# %% [markdown]
# # Assignment 1: detecting offensive content on twitter
# **Assignment due 1 March 2025 11:59pm**
#
# Welcome to the first assignment for 50.055 Machine Learning Operations. These assignments give you a chance to practice the methods and tools you have learned.
#
# **This assignment is an individual assignment.**
#
# - Read the instructions in this notebook carefully
# - Add your solution code and answers in the appropriate places. The questions are marked as **QUESTION:**, the places where you need to add your code and text answers are marked as **ADD YOUR SOLUTION HERE**
# - The completed notebook, including your added code and generated output, will be your submission for the assignment.
# - The notebook should execute without errors from start to finish when you select "Restart Kernel and Run All Cells..". Please test this before submission.
# - Use the SUTD Education Cluster or Google Colab to solve and test the assignment.
#
# **Rubric for assessment**
#
# Your submission will be graded using the following criteria.
# 1. Code executes: your code should execute without errors. The SUTD Education cluster should be used to ensure the same execution environment.
# 2. Correctness: the code should produce the correct result or the text answer should state the factual correct answer.
# 3. Style: your code should be written in a way that is clean and efficient. Your text answers should be relevant, concise and easy to understand.
# 4. Partial marks will be awarded for partially correct solutions.
# 5. There is a maximum of 76 points for this assignment.
#
#
# **ChatGPT policy:**
#
# If you use AI tools, such as ChatGPT, to solve the assignment questions, you need to be transparent about its use and mark AI-generated content as such. In particular, you should include the following in addition to your final answer:
# - A copy or screenshot of the prompt you used
# - The name of the AI model
# - The AI generated output
# - An explanation why the answer is correct or what you had to change to arrive at the correct answer
#
# **Assignment Notes:** Please make sure to save the notebook as you go along. Submission Instructions are located at the bottom of the notebook.

# %%
# Installing all required packages
# ----------------
! pip install transformers[torch]==4.37.2
! pip install evaluate==0.4.1
! pip install scikit-learn==1.4.0
! pip install datasets==2.17.1
! pip install wandb==0.16.3
! pip install seaborn==0.13.2
! pip install peft==0.10.0
! pip install accelerate==0.28.0
# ----------------
# Out:
# ^C
# Requirement already satisfied: transformers[torch]==4.37.2 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (4.37.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from transformers[torch]==4.37.2) (0.26.5)
# Requirement already satisfied: tqdm>=4.27 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from transformers[torch]==4.37.2) (4.67.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from transformers[torch]==4.37.2) (6.0.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from transformers[torch]==4.37.2) (24.2)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from transformers[torch]==4.37.2) (0.15.2)
# Requirement already satisfied: filelock in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from transformers[torch]==4.37.2) (3.13.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from transformers[torch]==4.37.2) (2024.11.6)
# Requirement already satisfied: numpy>=1.17 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from transformers[torch]==4.37.2) (1.23.5)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from transformers[torch]==4.37.2) (0.4.5)
# Requirement already satisfied: requests in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from transformers[torch]==4.37.2) (2.32.3)
# Requirement already satisfied: torch!=1.12.0,>=1.11 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from transformers[torch]==4.37.2) (2.5.1+cu118)
# Requirement already satisfied: accelerate>=0.21.0 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from transformers[torch]==4.37.2) (0.28.0)
# Requirement already satisfied: psutil in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from accelerate>=0.21.0->transformers[torch]==4.37.2) (6.1.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers[torch]==4.37.2) (4.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers[torch]==4.37.2) (2023.10.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from torch!=1.12.0,>=1.11->transformers[torch]==4.37.2) (1.13.1)
# Requirement already satisfied: networkx in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from torch!=1.12.0,>=1.11->transformers[torch]==4.37.2) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from torch!=1.12.0,>=1.11->transformers[torch]==4.37.2) (3.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from sympy==1.13.1->torch!=1.12.0,>=1.11->transformers[torch]==4.37.2) (1.3.0)
# Requirement already satisfied: colorama in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from tqdm>=4.27->transformers[torch]==4.37.2) (0.4.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from requests->transformers[torch]==4.37.2) (2024.8.30)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from requests->transformers[torch]==4.37.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from requests->transformers[torch]==4.37.2) (2.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from requests->transformers[torch]==4.37.2) (3.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from jinja2->torch!=1.12.0,>=1.11->transformers[torch]==4.37.2) (2.1.5)
# [notice] A new release of pip available: 22.2.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: evaluate==0.4.1 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (0.4.1)
# Requirement already satisfied: datasets>=2.0.0 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from evaluate==0.4.1) (2.17.1)
# Requirement already satisfied: responses<0.19 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from evaluate==0.4.1) (0.18.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from evaluate==0.4.1) (2.32.3)
# Requirement already satisfied: dill in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from evaluate==0.4.1) (0.3.8)
# Requirement already satisfied: multiprocess in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from evaluate==0.4.1) (0.70.16)
# Requirement already satisfied: huggingface-hub>=0.7.0 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from evaluate==0.4.1) (0.26.5)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from evaluate==0.4.1) (2023.10.0)
# Requirement already satisfied: packaging in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from evaluate==0.4.1) (24.2)
# Requirement already satisfied: xxhash in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from evaluate==0.4.1) (3.5.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from evaluate==0.4.1) (1.23.5)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from evaluate==0.4.1) (4.67.1)
# Requirement already satisfied: pandas in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from evaluate==0.4.1) (2.0.3)
# Requirement already satisfied: aiohttp in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from datasets>=2.0.0->evaluate==0.4.1) (3.11.13)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from datasets>=2.0.0->evaluate==0.4.1) (6.0.2)
# Requirement already satisfied: pyarrow>=12.0.0 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from datasets>=2.0.0->evaluate==0.4.1) (19.0.1)
# Requirement already satisfied: pyarrow-hotfix in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from datasets>=2.0.0->evaluate==0.4.1) (0.6)
# Requirement already satisfied: filelock in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from datasets>=2.0.0->evaluate==0.4.1) (3.13.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from huggingface-hub>=0.7.0->evaluate==0.4.1) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from requests>=2.19.0->evaluate==0.4.1) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from requests>=2.19.0->evaluate==0.4.1) (2.2.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from requests>=2.19.0->evaluate==0.4.1) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from requests>=2.19.0->evaluate==0.4.1) (2024.8.30)
# Requirement already satisfied: colorama in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from tqdm>=4.62.1->evaluate==0.4.1) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from pandas->evaluate==0.4.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from pandas->evaluate==0.4.1) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from pandas->evaluate==0.4.1) (2024.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate==0.4.1) (1.18.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate==0.4.1) (2.4.6)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate==0.4.1) (1.5.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate==0.4.1) (24.2.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate==0.4.1) (0.3.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate==0.4.1) (5.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate==0.4.1) (1.3.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate==0.4.1) (6.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->evaluate==0.4.1) (1.17.0)
# [notice] A new release of pip available: 22.2.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: scikit-learn==1.4.0 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from scikit-learn==1.4.0) (3.5.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from scikit-learn==1.4.0) (1.4.2)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from scikit-learn==1.4.0) (1.23.5)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from scikit-learn==1.4.0) (1.10.1)
# [notice] A new release of pip available: 22.2.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: datasets==2.17.1 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (2.17.1)
# [notice] A new release of pip available: 22.2.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from datasets==2.17.1) (0.3.8)
# Requirement already satisfied: pyarrow>=12.0.0 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from datasets==2.17.1) (19.0.1)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from datasets==2.17.1) (4.67.1)
# Requirement already satisfied: filelock in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from datasets==2.17.1) (3.13.1)
# Requirement already satisfied: pandas in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from datasets==2.17.1) (2.0.3)
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from datasets==2.17.1) (2023.10.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from datasets==2.17.1) (6.0.2)
# Requirement already satisfied: multiprocess in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from datasets==2.17.1) (0.70.16)
# Requirement already satisfied: huggingface-hub>=0.19.4 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from datasets==2.17.1) (0.26.5)
# Requirement already satisfied: pyarrow-hotfix in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from datasets==2.17.1) (0.6)
# Requirement already satisfied: packaging in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from datasets==2.17.1) (24.2)
# Requirement already satisfied: requests>=2.19.0 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from datasets==2.17.1) (2.32.3)
# Requirement already satisfied: xxhash in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from datasets==2.17.1) (3.5.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from datasets==2.17.1) (1.23.5)
# Requirement already satisfied: aiohttp in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from datasets==2.17.1) (3.11.13)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from aiohttp->datasets==2.17.1) (5.0.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from aiohttp->datasets==2.17.1) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from aiohttp->datasets==2.17.1) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from aiohttp->datasets==2.17.1) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from aiohttp->datasets==2.17.1) (1.18.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from aiohttp->datasets==2.17.1) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from aiohttp->datasets==2.17.1) (24.2.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from aiohttp->datasets==2.17.1) (2.4.6)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from huggingface-hub>=0.19.4->datasets==2.17.1) (4.9.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from requests>=2.19.0->datasets==2.17.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from requests>=2.19.0->datasets==2.17.1) (2.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from requests>=2.19.0->datasets==2.17.1) (3.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from requests>=2.19.0->datasets==2.17.1) (2024.8.30)
# Requirement already satisfied: colorama in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from tqdm>=4.62.1->datasets==2.17.1) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from pandas->datasets==2.17.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from pandas->datasets==2.17.1) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from pandas->datasets==2.17.1) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\parthasarathy.harini\downloads\nlp\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets==2.17.1) (1.17.0)

# %%
# Importing all required packages
# ----------------
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import SGDClassifier
from sklearn import metrics

import pandas as pd
import numpy as np
import evaluate
import time

import seaborn as sns
import matplotlib.pyplot as plt

import transformers
from transformers import AutoTokenizer
from transformers import TrainingArguments, Trainer
from datasets import load_dataset
# ----------------

# %%
# %matplotlib inline

# %% [markdown]
# # Offensive language detection
#
# Content moderation of offensive or hateful language is an important task on social media platforms.
# In this assignment, you will train a text classification models for detecting offensive language on twitter. You will run experiments with different models and evaluate their performance and costs.
#
# We will use the TweetEval data set from Barbiert et al (2020): https://aclanthology.org/2020.findings-emnlp.148.pdf
#
#
# **Warning**
# Some of the content contains rude and offensive language. If you know that this causes you distress, let the course instructor know to arrange a different assessment.

# %%
# load data set
dataset = load_dataset("tweet_eval", "offensive")
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 11916
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 860
#     })
#     validation: Dataset({
#         features: ['text', 'label'],
#         num_rows: 1324
#     })
# })

# %%
# QUESTION: print the first training set sample

#--- ADD YOUR SOLUTION HERE (1 point)---

print(dataset["train"][0])
#------------------------------
# Hint: you should see a tweet about U2 singer Bono
# Out:
# {'text': '@user Bono... who cares. Soon people will understand that they gain nothing from following a phony celebrity. Become a Leader of your people instead or help and support your fellow countrymen.', 'label': 0}

# %%
# QUESTION: what are the possible values of the labels? What is their meaning?
# Print the set of label values and their label names
#--- ADD YOUR SOLUTION HERE (5 points) ---

unique_labels = set(dataset["train"]["label"])
print(f"Possible label values: {unique_labels}")

# -------
# Hint: it is a binary task
# Out:
# Possible label values: {0, 1}

# %%
label_meanings = {
    0: "Not Offensive",
    1: "Offensive"
}
for label in sorted(unique_labels):
    print(f"Label {label}: {label_meanings[label]}")
# Out:
# Label 0: Not Offensive
# Label 1: Offensive

# %%
# QUESTION: plot a bar chart of the label distribution
#--- ADD YOUR SOLUTION HERE (5 points) ---
from collections import Counter

label_counts = Counter(dataset["train"]["label"])
labels = sorted(label_counts.keys())
counts = [label_counts[label] for label in labels]
label_names = ["Not Offensive", "Offensive"]

plt.figure(figsize=(10, 6))
bars = plt.bar(label_names, counts, color=['skyblue', 'salmon'])

for bar, count in zip(bars, counts):
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 100,
             str(count), ha='center', va='bottom')

plt.xlabel('Label')
plt.ylabel('Count')
plt.title('Distribution of Labels in Tweet Eval Offensive Dataset')

plt.grid(axis='y', linestyle='--', alpha=0.7)


plt.tight_layout()
plt.show()

#------------------------------
# Hint: it is not evenly distributed

# %%
# QUESTION: separate data set into training, validation and test according to given dataset split
# You should end up with the following variables
# train_text = array containing strings in training set
# train_labels = array containing numeric labels in training set
# validation_text = array containing strings in training set
# validation_labels = array containing numeric labels in training set
# test_text = array containing strings in training set
# test_labels = array containing numeric labels in training set

#--- ADD YOUR SOLUTION HERE (10 points) ---

train_text = np.array(dataset["train"]["text"])
train_labels = np.array(dataset["train"]["label"])

validation_text = np.array(dataset["validation"]["text"])
validation_labels = np.array(dataset["validation"]["label"])

test_text = np.array(dataset["test"]["text"])
test_labels = np.array(dataset["test"]["label"])

#------------------------------

# %%
# check the size of the data splits
print("#train: ", len(train_text))
print("#validation: ", len(validation_text))
print("#test: ", len(test_text))

# Hint: you should see
#train:  11916
#validation:  1324
#test:  860
# Out:
# #train:  11916
# #validation:  1324
# #test:  860

# %%
#
# QUESTION: create a scikit-learn pipeline object that creates unigram features, applies tf-idf weighting and trains a SGDClassifier
# tf-idf stands for “Term Frequency times Inverse Document Frequency”.
# tf-idf is a feature weighting methods commonly used in NLP and IR
# use default parameters for unigram feature extraction, tf-idf and the SGDClassifier
# add additional import statements in this cell as needed

#--- ADD YOUR SOLUTION HERE (10 points) ---
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.linear_model import SGDClassifier
pipeline = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
    ('clf', SGDClassifier())
])
#------------------------------
# Hint: use the scikit-learn library

# %% [markdown]
# # Train the model

# %%
#
# QUESTION: apply your pipeline of feature extraction and model training to the training set
# Measure the wall-clock training time needed
# Store the training time in a variable 'train_time_sgd
#--- ADD YOUR SOLUTION HERE (5 points) ---
start_time = time.time()
pipeline.fit(train_text, train_labels)
train_time_sgd = time.time() - start_time
#------------------------------

# %%
print(f"Training time: {train_time_sgd}s")

# Hint: training should take < 1 sec
# Out:
# Training time: 0.25107622146606445s

# %% [markdown]
# # Test the model

# %%
from sklearn.metrics import classification_report, precision_recall_fscore_support
from collections import Counter
import numpy as np
# QUESTION: compute the majority class baseline score on the validation set and test set
# the majority class baseline is the score you get if you always predict the most frequent label
#
# Compute the precision, recall and F1 score for the majority baseline for validation and test set for each class
#
#--- ADD YOUR SOLUTION HERE (5 points) ---

counts = Counter(train_labels)
most_common = counts.most_common()
majority_class = most_common[0][0]  

print(majority_class)
print(label_meanings[majority_class])
majority_preds_valid = []
for i in range(len(validation_labels)):
    majority_preds_valid.append(majority_class)
majority_preds_valid = np.array(majority_preds_valid)

majority_preds_test = []
for i in range(len(test_labels)):
    majority_preds_test.append(majority_class)
majority_preds_test = np.array(majority_preds_test)


print("VALIDATION SET RESULTS:")
print("=" * 30)
val_report = classification_report(validation_labels, majority_preds_valid, 
                                  target_names=list(label_meanings.values()))
print(val_report)

val_precision, val_recall, val_f1, _ = precision_recall_fscore_support(
    validation_labels, majority_preds_valid, average=None
)


print("TEST SET RESULTS:")
print("=" * 30)
test_report = classification_report(test_labels, majority_preds_test,
                                   target_names=list(label_meanings.values()))
print(test_report)
test_precision, test_recall, test_f1, _ = precision_recall_fscore_support(
    test_labels, majority_preds_test, average=None
)

print("DETAILED VALIDATION METRICS")
print("=" * 30)
for i in range(len(label_meanings)):
    class_name = label_meanings[i]
    print(f"Class {i} - {class_name}:")
    print(f"  Precision: {val_precision[i]}")  
    print(f"  Recall: {val_recall[i]}")
    print(f"  F1: {val_f1[i]}")
    print("-" * 20)

print("DETAILED TEST METRICS:")
print("=" * 30)
for i in range(len(label_meanings)):
    class_name = label_meanings[i]
    print(f"Class {i} - {class_name}:")
    print(f"  Precision: {test_precision[i]}")
    print(f"  Recall: {test_recall[i]}")  
    print(f"  F1: {test_f1[i]}")
    print("-" * 20)

#------------------------------
# Out:
# 0
# Not Offensive
# VALIDATION SET RESULTS:
# ==============================
#                precision    recall  f1-score   support
#
# Not Offensive       0.65      1.00      0.79       865
#     Offensive       0.00      0.00      0.00       459
#
#      accuracy                           0.65      1324
#     macro avg       0.33      0.50      0.40      1324
#  weighted avg       0.43      0.65      0.52      1324
#
# TEST SET RESULTS:
# ==============================
#                precision    recall  f1-score   support
#
# Not Offensive       0.72      1.00      0.84       620
#     Offensive       0.00      0.00      0.00       240
#
#      accuracy                           0.72       860
#     macro avg       0.36      0.50      0.42       860
#  weighted avg       0.52      0.72      0.60       860
#
# DETAILED VALIDATION METRICS
# ==============================
# Class 0 - Not Offensive:
#   Precision: 0.6533232628398792
#   Recall: 1.0
#   F1: 0.7903152124257652
# --------------------
# Class 1 - Offensive:
#   Precision: 0.0
#   Recall: 0.0
#   F1: 0.0
# --------------------
# DETAILED TEST METRICS:
# ==============================
# Class 0 - Not Offensive:
#   Precision: 0.7209302325581395
#   Recall: 1.0
#   F1: 0.8378378378378378
# --------------------
# Class 1 - Offensive:
#   Precision: 0.0
#   Recall: 0.0
#   F1: 0.0
# --------------------
# c:\Users\Parthasarathy.Harini\Downloads\NLP\.venv\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Parthasarathy.Harini\Downloads\NLP\.venv\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Parthasarathy.Harini\Downloads\NLP\.venv\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Parthasarathy.Harini\Downloads\NLP\.venv\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Parthasarathy.Harini\Downloads\NLP\.venv\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Parthasarathy.Harini\Downloads\NLP\.venv\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Parthasarathy.Harini\Downloads\NLP\.venv\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Parthasarathy.Harini\Downloads\NLP\.venv\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
#
#
# QUESTION: now use your pipeline to make predictions on validation and test set
# compute and print accuracy, precision, recall, F1 score
#
# From now on, we are only concerned with the F1 score for the "positive" class which are the offensive tweets
# Store the test F1 score for the "positive" class in a variable 'f1_validation_sgd' and 'f1_test_sgd' for validation and test set, respectively
#--- ADD YOUR SOLUTION HERE (10 points) ---
from sklearn.metrics import classification_report, precision_recall_fscore_support, accuracy_score

validation_predictions = pipeline.predict(validation_text)
test_predictions = pipeline.predict(test_text)

# Validation set metrics
print("Val Set:")
validation_precision, validation_recall, validation_f1, _ = precision_recall_fscore_support(
    validation_labels, validation_predictions, average=None
)
validation_accuracy = accuracy_score(validation_labels, validation_predictions)
print(f"Acc: {validation_accuracy}")
print(classification_report(validation_labels, validation_predictions,
                          target_names=list(label_meanings.values())))

# Test set metrics 
print("\nTest Set:")
test_precision, test_recall, test_f1, _ = precision_recall_fscore_support(
    test_labels, test_predictions, average=None
)
test_accuracy = accuracy_score(test_labels, test_predictions)
print(f"Acc: {test_accuracy}")
print(classification_report(test_labels, test_predictions,
                          target_names=list(label_meanings.values())))

f1_validation_sgd = validation_f1[1]  
f1_test_sgd = test_f1[1]  

print("\nf1_validation_sgd:")
print(f'{f1_validation_sgd}')
print(f"test f1 sccore: {f1_test_sgd}")

#------------------------------
# Hint: F1 scores should be >50%
# Out:
# Val Set:
# Acc: 0.7598187311178247
#                precision    recall  f1-score   support
#
# Not Offensive       0.75      0.95      0.84       865
#     Offensive       0.82      0.39      0.53       459
#
#      accuracy                           0.76      1324
#     macro avg       0.78      0.67      0.69      1324
#  weighted avg       0.77      0.76      0.73      1324
#
#
# Test Set:
# Acc: 0.8046511627906977
#                precision    recall  f1-score   support
#
# Not Offensive       0.80      0.97      0.88       620
#     Offensive       0.82      0.38      0.52       240
#
#      accuracy                           0.80       860
#     macro avg       0.81      0.68      0.70       860
#  weighted avg       0.81      0.80      0.78       860
#
#
# f1_validation_sgd:
# 0.5323529411764706
# test f1 sccore: 0.5227272727272727

# %% [markdown]
# # BERT model
#
# Now let us try a more powerful model: the DistilBERT uncased model
#
# https://huggingface.co/distilbert-base-uncased

# %%
# load DistilBERT tokenizer and tokenize data set
model_name = "distilbert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_name)

def tokenize_function(examples):
    return tokenizer(examples["text"], padding="max_length", truncation=True)

tokenized_datasets = dataset.map(tokenize_function, batched=True)
train_dataset = tokenized_datasets["train"]
eval_dataset = tokenized_datasets["validation"]
test_dataset = tokenized_datasets["test"]
# Out:
# c:\Users\Parthasarathy.Harini\Downloads\NLP\.venv\lib\site-packages\huggingface_hub\file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Map:   0%|          | 0/860 [00:00<?, ? examples/s]

# %%
# load DistilBERT model for classification

#--- ADD YOUR SOLUTION HERE (5 points) ---
from transformers import AutoModelForSequenceClassification

# Initialize the model with the appropriate number of labels (2 for binary classification)
model = AutoModelForSequenceClassification.from_pretrained(
    model_name,
    num_labels=2  # Binary classification: Not Offensive (0) and Offensive (1)
)
#------------------------------
# Hint: make sure your model corresponds to your tokenizer
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# add custom metrics that computes precision, recall, f1, accuracy

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)

    # Calculate accuracy
    accuracy = accuracy_score(labels, preds)

   # Calculate precision, recall, and F1-score
    precision = precision_score(labels, preds, average='binary')
    recall = recall_score(labels, preds, average='binary')
    f1 = f1_score(labels, preds, average='binary')

    return {
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1': f1
    }

# %%
#
# QUESTION: configure the training parameters using the Huggingface TrainingArguments class
# - set the output directory to "finetuning-tweeteval"
# - do not report training metrics to an external experiment tracking service
# - print acc/p/r/f1 scores on the validation set every 200 steps
# - learning rate to 2e-5,
# - set weight decay to 0.01
# - set epochs to 1


#--- ADD YOUR SOLUTION HERE (5 points) ---

from transformers import TrainingArguments

training_args = TrainingArguments(
    output_dir="finetuning-tweeteval",
    report_to="none",  # Do not report training metrics to external services
    evaluation_strategy="steps",
    eval_steps=200,  # Evaluate every 200 steps
    learning_rate=2e-5,
    weight_decay=0.01,
    num_train_epochs=1,
    save_strategy="no",  # Not saving checkpoints for this simple example
    logging_dir="./logs",
    logging_steps=200,  # Log every 200 steps
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
)

#------------------------------

# %%
# initialize trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    compute_metrics=compute_metrics,
)
# Out:
# c:\Users\Parthasarathy.Harini\Downloads\NLP\.venv\lib\site-packages\accelerate\accelerator.py:432: FutureWarning: Passing the following arguments to `Accelerator` is deprecated and will be removed in version 1.0 of Accelerate: dict_keys(['dispatch_batches', 'split_batches']). Please pass an `accelerate.DataLoaderConfiguration` instead:
# dataloader_config = DataLoaderConfiguration(dispatch_batches=None, split_batches=False)
#   warnings.warn(

# %%
# train the model
train_output = trainer.train()
# Out:
#   0%|          | 0/745 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 2
#       1 # train the model
# ----> 2 train_output = trainer.train()
#
# File c:\Users\Parthasarathy.Harini\Downloads\NLP\.venv\lib\site-packages\transformers\trainer.py:1539, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1537         hf_hub_utils.enable_progress_bars()
#    1538 else:
# -> 1539     return inner_training_loop(
#    1540         args=args,
#    1541         resume_from_checkpoint=resume_from_checkpoint,
#    1542         trial=trial,
#    1543         ignore_keys_for_eval=ignore_keys_for_eval,
#    1544     )
#
# File c:\Users\Parthasarathy.Harini\Downloads\NLP\.venv\lib\site-packages\transformers\trainer.py:1869, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1866     self.control = self.callback_handler.on_step_begin(args, self.state, self.control)
#    1868 with self.accelerator.accumulate(model):
# -> 1869     tr_loss_step = self.training_step(model, inputs)
#    1871 if (
#    1872     args.logging_nan_inf_filter
#    1873     and not is_torch_tpu_available()
#    1874     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    1875 ):
#    1876     # if loss is nan or inf simply add the average of previous logged losses
#    1877     tr_loss += tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File c:\Users\Parthasarathy.Harini\Downloads\NLP\.venv\lib\site-packages\transformers\trainer.py:2781, in Trainer.training_step(self, model, inputs)
#    2779         scaled_loss.backward()
#    2780 else:
# -> 2781     self.accelerator.backward(loss)
#    2783 return loss.detach() / self.args.gradient_accumulation_steps
#
# File c:\Users\Parthasarathy.Harini\Downloads\NLP\.venv\lib\site-packages\accelerate\accelerator.py:2001, in Accelerator.backward(self, loss, **kwargs)
#    1999     self.scaler.scale(loss).backward(**kwargs)
#    2000 else:
# -> 2001     loss.backward(**kwargs)
#
# File c:\Users\Parthasarathy.Harini\Downloads\NLP\.venv\lib\site-packages\torch\_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     571 if has_torch_function_unary(self):
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)
#     579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File c:\Users\Parthasarathy.Harini\Downloads\NLP\.venv\lib\site-packages\torch\autograd\__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File c:\Users\Parthasarathy.Harini\Downloads\NLP\.venv\lib\site-packages\torch\autograd\graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
# Evaluate on training set 
trainer.evaluate(train_dataset)
# Out:
#   0%|          | 0/745 [00:00<?, ?it/s]
# {'eval_loss': 0.3718287944793701,
#  'eval_accuracy': 0.840802282645183,
#  'eval_precision': 0.786114221724524,
#  'eval_recall': 0.7125095153514337,
#  'eval_f1': 0.747504325835219,
#  'eval_runtime': 269.3388,
#  'eval_samples_per_second': 44.242,
#  'eval_steps_per_second': 2.766,
#  'epoch': 1.0}

# %%
# Evaluate on validation set
trainer.evaluate(eval_dataset)
# Out:
#   0%|          | 0/83 [00:00<?, ?it/s]
# {'eval_loss': 0.41940781474113464,
#  'eval_accuracy': 0.8036253776435045,
#  'eval_precision': 0.745679012345679,
#  'eval_recall': 0.6579520697167756,
#  'eval_f1': 0.6990740740740741,
#  'eval_runtime': 30.044,
#  'eval_samples_per_second': 44.069,
#  'eval_steps_per_second': 2.763,
#  'epoch': 1.0}

# %%
# Evaluate on test set
test_output = trainer.evaluate(test_dataset)
print(test_output)
# Out:
#   0%|          | 0/54 [00:00<?, ?it/s]
# {'eval_loss': 0.36897554993629456, 'eval_accuracy': 0.8534883720930233, 'eval_precision': 0.796875, 'eval_recall': 0.6375, 'eval_f1': 0.7083333333333334, 'eval_runtime': 19.6811, 'eval_samples_per_second': 43.697, 'eval_steps_per_second': 2.744, 'epoch': 1.0}

# %% [markdown]
# ### QUESTION:
# Do you see any signs of overfitting or underfitting based on the evaluation scores
# Explain why or why not
#
# **--- ADD YOUR SOLUTION HERE (5 points) ---**
#
# ------------------------------

# %% [markdown]
# There's not much difference between how the model does on training data (F1 score 0.7475) versus test data (F1 score 0.7083). That 4% gap seems normal - not a red flag for overfitting. The model actually does better on the completely new test data than validation data, which is a good sign.  And it doesn't seem to be underfitting either since it's getting decent scores (around 70%) across the board. which indicates that it learned the task.

# %%
#
# QUESTION: What is the ratio f1 score to training time for the SGDClassifier and the DistilBERT model
# compute the two ratios and print them

#--- ADD YOUR SOLUTION HERE ---
f1_test_sgd = 0.5198 
train_time_sgd = 0.4022 
f1_test_bert = 0.7083  
train_time_bert = 748.7399 
ratio_sgd = f1_test_sgd / train_time_sgd
ratio_bert = f1_test_bert / train_time_bert
print(f"SGD : {ratio_sgd}")
print(f"DistilBERT : {ratio_bert}")
#------------------------------
# Out:
# SGD : 1.292391844853307
# DistilBERT : 0.0009459893883042697

# %% [markdown]
# ### QUESTION:
# Given the results what model would you recommend to use? Write a paragraph (max 200 words) to explain your choice
#
# **--- ADD YOUR SOLUTION HERE (10 points)---**
#
# ------------------------------

# %% [markdown]
# I think SGDClassifier is better as even though distilbert has better F1 score, the training time difference is drastic. I believe that in most use cases, for eg. real-time tweet moderation systems efficiency would be of higher priority, not only that but during my training, when i ran distilbert on a non-gpu system i found that the training time is significantly higher which means SGD classifier also takes much less compute resources to deplOY and use.

# %% [markdown]
# # End
#
# This concludes assignment 1.
#
#
# Please submit this notebook with your answers and the generated output cells as a **Jupyter notebook file** via github.
#
#
# 1. Create a private github repository **sutd_5055mlop** under your github user.
# 2. Add your instructors as collaborator: ddahlmeier and lucainiaoge
# 3. Save your submission as assignment_01_STUDENT_NAME.ipynb where STUDENT_NAME is your name in your SUTD email address.
# 4. Push the submission file to your repo
# 5. Submit the link to the repo via eDimensions
#
# Example:<br/>
# Email: michael_tan@mymail.sutd.edu.sg<br/>
# STUDENT_NAME: michael_tan<br/>
# Submission file name: assignment_01_michael_tan.ipynb
#
#
#
# **Assignment due 01 March 2025 11:59pm**
